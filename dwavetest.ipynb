# %%
from dwave.system import DWaveSampler, EmbeddingComposite
import dimod

# Define a simple Ising problem
h = {}  # No linear biases
J = {(0, 1): -1}  # One interaction

sampler = EmbeddingComposite(DWaveSampler())
response = sampler.sample_ising(h, J, num_reads=100)

print(response)
# Out:
# ---------------------------------------------------------------------------
# ResourceAuthenticationError               Traceback (most recent call last)
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/client/base.py:1094, in Client.get_solvers(self, refresh, order_by, **filters)
#    1093 try:
# -> 1094     solvers = self._fetch_solvers(**query)
#    1096 # wrap exceptions for backwards-compatibility
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/client/base.py:726, in Client._fetch_solvers(self, name, refresh_)
#     724 logger.info("Fetching definitions of all available solvers")
# --> 726 solvers = self.solvers_session.list_solvers(
#     727     filter=static_fields, refresh_=refresh_)
#     728 dynamic = self.solvers_session.list_solvers(
#     729     filter=dynamic_fields, refresh_=refresh_,
#     730     maxage_=self._DEFAULT_SOLVERS_DYNAMIC_PART_MAXAGE)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/resources.py:53, in accepts.__call__.<locals>.wrapper(obj, *args, **kwargs)
#      52     obj.session.set_accept(**self.ctx)
# ---> 53     return fn(obj, *args, **kwargs)
#      55 finally:
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/resources.py:132, in Solvers.list_solvers(self, filter, **kwargs)
#     131 params = {'filter': filter} if filter is not None else None
# --> 132 response = self.session.get(path, params=params, **kwargs)
#     133 # see asv benchmarks `JSONResponseDecode` for json -> model performance
#     134 # tl;dr: model_validate() on orjson-decoded content is much faster then
#     135 #        model_validate_json() and faster than model_validate on json-decoded
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/client.py:467, in CachingSession.request(self, method, url, params, headers, **kwargs)
#     466 logger.debug('cache miss, updating cache')
# --> 467 res = super().request(method, url, params=params, headers=headers, **kwargs)
#     468 self._update_cache(res, key_meta=key_meta, key_data=key_data)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/client.py:228, in VersionedAPISession.request(self, headers, *args, **kwargs)
#     226     headers['Accept'] = werkzeug.http.dump_options_header(self._media_type, params)
# --> 228 response = super().request(*args, headers=headers, **kwargs)
#     230 # (2) validate format/version supported in the incoming response
#     231 #     (validate `Content-Type` if `media_type` and/or `accept_version` set)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/client.py:97, in LoggingSession.request(self, method, *args, **kwargs)
#      96 try:
# ---> 97     response = self._request_unified(method, *args, **kwargs)
#      99     rec = LoggingSession.RequestRecord(
#     100         request=response.request, response=response, exception=None)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/client.py:65, in LoggingSession._request_unified(self, method, *args, **kwargs)
#      64 try:
# ---> 65     return super().request(method, *args, **kwargs)
#      66 except Exception as exc:
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/utils/http.py:85, in BaseUrlSession.request(self, method, url, *args, **kwargs)
#      84 url = self.create_url(url)
# ---> 85 return super().request(method, url, *args, **kwargs)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/client.py:85, in LoggingSession.send(self, request, **kwargs)
#      83     logger.trace(f"[{callee!s}] send(method={request.method!r}, url={request.url!r},"
#      84                  f" headers={request.headers!r}, body={request.body!r})")
# ---> 85 return super().send(request, **kwargs)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/requests/sessions.py:710, in Session.send(self, request, **kwargs)
#     709 # Response manipulation hooks
# --> 710 r = dispatch_hook("response", hooks, r, **kwargs)
#     712 # Persist cookies
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/requests/hooks.py:30, in dispatch_hook(key, hooks, hook_data, **kwargs)
#      29 for hook in hooks:
# ---> 30     _hook_data = hook(hook_data, **kwargs)
#      31     if _hook_data is not None:
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/client.py:716, in DWaveAPIClient._raise_for_status(response, **kwargs)
#     715 if error_code in exception_map:
# --> 716     raise exception_map[error_code](**kw)
#     717 elif 500 <= error_code < 600:
#
# ResourceAuthenticationError: Unauthorized
#
# The above exception was the direct cause of the following exception:
#
# SolverAuthenticationError                 Traceback (most recent call last)
# Cell In[2], line 8
#       5 h = {}  # No linear biases
#       6 J = {(0, 1): -1}  # One interaction
# ----> 8 sampler = EmbeddingComposite(DWaveSampler())
#       9 response = sampler.sample_ising(h, J, num_reads=100)
#      11 print(response)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/system/samplers/dwave_sampler.py:181, in DWaveSampler.__init__(self, failover, retry_interval, **config)
#     178 self._solver_penalty = defaultdict(int)
#     180 self.client = Client.from_config(**config)
# --> 181 self.solver = self._get_solver(penalty=self._solver_penalty)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/system/samplers/dwave_sampler.py:196, in DWaveSampler._get_solver(self, refresh, penalty)
#     194 filters = copy.deepcopy(self.client.config.solver)
#     195 order_by = filters.pop('order_by', 'avg_load')
# --> 196 solvers = self.client.get_solvers(refresh=refresh, order_by=order_by, **filters)
#     198 # we now just need to de-prioritize penalized solvers
#     199 solvers.sort(key=lambda solver: penalty.get(solver.id, 0))
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/events.py:109, in dispatches_events.__call__.<locals>.wrapped(*pargs, **kwargs)
#     104 @wraps(fn)
#     105 def wrapped(*pargs, **kwargs):
#     106     if not (has_handler(self.before_eventname) or
#     107             has_handler(self.after_eventname)):
#     108         # skip dispatch altogether
# --> 109         return fn(*pargs, **kwargs)
#     111     sig = inspect.signature(fn)
#     112     bound = sig.bind(*pargs, **kwargs)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/client/base.py:1098, in Client.get_solvers(self, refresh, order_by, **filters)
#    1096 # wrap exceptions for backwards-compatibility
#    1097 except api.exceptions.ResourceAuthenticationError as e:
# -> 1098     raise SolverAuthenticationError from e
#    1099 except api.exceptions.ResourceBadResponseError as e:
#    1100     raise InvalidAPIResponseError(e) from e
#
# SolverAuthenticationError: Invalid token or access denied

# %%
from dwave.system import DWaveSampler

sampler = DWaveSampler()
print("Connected to D-Wave!")
# Out:
# ---------------------------------------------------------------------------
# ResourceAuthenticationError               Traceback (most recent call last)
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/client/base.py:1094, in Client.get_solvers(self, refresh, order_by, **filters)
#    1093 try:
# -> 1094     solvers = self._fetch_solvers(**query)
#    1096 # wrap exceptions for backwards-compatibility
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/client/base.py:726, in Client._fetch_solvers(self, name, refresh_)
#     724 logger.info("Fetching definitions of all available solvers")
# --> 726 solvers = self.solvers_session.list_solvers(
#     727     filter=static_fields, refresh_=refresh_)
#     728 dynamic = self.solvers_session.list_solvers(
#     729     filter=dynamic_fields, refresh_=refresh_,
#     730     maxage_=self._DEFAULT_SOLVERS_DYNAMIC_PART_MAXAGE)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/resources.py:53, in accepts.__call__.<locals>.wrapper(obj, *args, **kwargs)
#      52     obj.session.set_accept(**self.ctx)
# ---> 53     return fn(obj, *args, **kwargs)
#      55 finally:
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/resources.py:132, in Solvers.list_solvers(self, filter, **kwargs)
#     131 params = {'filter': filter} if filter is not None else None
# --> 132 response = self.session.get(path, params=params, **kwargs)
#     133 # see asv benchmarks `JSONResponseDecode` for json -> model performance
#     134 # tl;dr: model_validate() on orjson-decoded content is much faster then
#     135 #        model_validate_json() and faster than model_validate on json-decoded
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/client.py:467, in CachingSession.request(self, method, url, params, headers, **kwargs)
#     466 logger.debug('cache miss, updating cache')
# --> 467 res = super().request(method, url, params=params, headers=headers, **kwargs)
#     468 self._update_cache(res, key_meta=key_meta, key_data=key_data)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/client.py:228, in VersionedAPISession.request(self, headers, *args, **kwargs)
#     226     headers['Accept'] = werkzeug.http.dump_options_header(self._media_type, params)
# --> 228 response = super().request(*args, headers=headers, **kwargs)
#     230 # (2) validate format/version supported in the incoming response
#     231 #     (validate `Content-Type` if `media_type` and/or `accept_version` set)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/client.py:97, in LoggingSession.request(self, method, *args, **kwargs)
#      96 try:
# ---> 97     response = self._request_unified(method, *args, **kwargs)
#      99     rec = LoggingSession.RequestRecord(
#     100         request=response.request, response=response, exception=None)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/client.py:65, in LoggingSession._request_unified(self, method, *args, **kwargs)
#      64 try:
# ---> 65     return super().request(method, *args, **kwargs)
#      66 except Exception as exc:
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/utils/http.py:85, in BaseUrlSession.request(self, method, url, *args, **kwargs)
#      84 url = self.create_url(url)
# ---> 85 return super().request(method, url, *args, **kwargs)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/client.py:85, in LoggingSession.send(self, request, **kwargs)
#      83     logger.trace(f"[{callee!s}] send(method={request.method!r}, url={request.url!r},"
#      84                  f" headers={request.headers!r}, body={request.body!r})")
# ---> 85 return super().send(request, **kwargs)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/requests/sessions.py:710, in Session.send(self, request, **kwargs)
#     709 # Response manipulation hooks
# --> 710 r = dispatch_hook("response", hooks, r, **kwargs)
#     712 # Persist cookies
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/requests/hooks.py:30, in dispatch_hook(key, hooks, hook_data, **kwargs)
#      29 for hook in hooks:
# ---> 30     _hook_data = hook(hook_data, **kwargs)
#      31     if _hook_data is not None:
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/api/client.py:716, in DWaveAPIClient._raise_for_status(response, **kwargs)
#     715 if error_code in exception_map:
# --> 716     raise exception_map[error_code](**kw)
#     717 elif 500 <= error_code < 600:
#
# ResourceAuthenticationError: Unauthorized
#
# The above exception was the direct cause of the following exception:
#
# SolverAuthenticationError                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from dwave.system import DWaveSampler
# ----> 3 sampler = DWaveSampler()
#       4 print("Connected to D-Wave!")
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/system/samplers/dwave_sampler.py:181, in DWaveSampler.__init__(self, failover, retry_interval, **config)
#     178 self._solver_penalty = defaultdict(int)
#     180 self.client = Client.from_config(**config)
# --> 181 self.solver = self._get_solver(penalty=self._solver_penalty)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/system/samplers/dwave_sampler.py:196, in DWaveSampler._get_solver(self, refresh, penalty)
#     194 filters = copy.deepcopy(self.client.config.solver)
#     195 order_by = filters.pop('order_by', 'avg_load')
# --> 196 solvers = self.client.get_solvers(refresh=refresh, order_by=order_by, **filters)
#     198 # we now just need to de-prioritize penalized solvers
#     199 solvers.sort(key=lambda solver: penalty.get(solver.id, 0))
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/events.py:109, in dispatches_events.__call__.<locals>.wrapped(*pargs, **kwargs)
#     104 @wraps(fn)
#     105 def wrapped(*pargs, **kwargs):
#     106     if not (has_handler(self.before_eventname) or
#     107             has_handler(self.after_eventname)):
#     108         # skip dispatch altogether
# --> 109         return fn(*pargs, **kwargs)
#     111     sig = inspect.signature(fn)
#     112     bound = sig.bind(*pargs, **kwargs)
#
# File ~/miniconda3/envs/dwaveenv/lib/python3.13/site-packages/dwave/cloud/client/base.py:1098, in Client.get_solvers(self, refresh, order_by, **filters)
#    1096 # wrap exceptions for backwards-compatibility
#    1097 except api.exceptions.ResourceAuthenticationError as e:
# -> 1098     raise SolverAuthenticationError from e
#    1099 except api.exceptions.ResourceBadResponseError as e:
#    1100     raise InvalidAPIResponseError(e) from e
#
# SolverAuthenticationError: Invalid token or access denied
